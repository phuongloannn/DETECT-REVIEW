# %%
import os

# Tạo thư mục templates nếu chưa có
os.makedirs("templates", exist_ok=True)

# Nội dung index.html
html_content = """
<!DOCTYPE html>
<html lang="vi">
<head>
    <meta charset="UTF-8">
    <title>Phân Tích Đánh Giá Giả</title>
    <link href="https://fonts.googleapis.com/css2?family=Poppins:wght@400;600&display=swap" rel="stylesheet">
    <style>
        * {
            box-sizing: border-box;
        }

        body {
            font-family: 'Poppins', sans-serif;
            background: linear-gradient(135deg, #e0c3fc, #8ec5fc);
            margin: 0;
            padding: 0;
            display: flex;
            align-items: center;
            justify-content: center;
            min-height: 100vh;
        }

        .container {
            background: #fff;
            max-width: 700px;
            width: 90%;
            margin: auto;
            padding: 40px;
            border-radius: 20px;
            box-shadow: 0 12px 30px rgba(0, 0, 0, 0.1);
            animation: fadeIn 1s ease-in-out;
        }

        @keyframes fadeIn {
            from { opacity: 0; transform: translateY(20px); }
            to { opacity: 1; transform: translateY(0); }
        }

        h2 {
            text-align: center;
            color: #6a0dad;
            margin-bottom: 30px;
        }

        label {
            display: block;
            margin-top: 15px;
            font-weight: 600;
            color: #333;
        }

        textarea, select, button {
            width: 100%;
            margin-top: 10px;
            padding: 12px;
            font-size: 16px;
            border-radius: 12px;
            border: 1px solid #ccc;
            font-family: 'Poppins', sans-serif;
        }

        button {
            background: #8e44ad;
            color: #fff;
            font-weight: 600;
            border: none;
            cursor: pointer;
            margin-top: 20px;
            transition: background 0.3s ease;
        }

        button:hover {
            background: #6c3483;
        }

        .result {
            margin-top: 30px;
            font-size: 18px;
            text-align: center;
            padding: 15px;
            border-radius: 10px;
            font-weight: bold;
        }

        .true {
            background: #d4edda;
            color: #155724;
        }

        .fake {
            background: #f8d7da;
            color: #721c24;
        }

        @media (max-width: 600px) {
            .container {
                padding: 25px;
            }
        }
    </style>
</head>
<body>
    <h1>Phân tích Review</h1>
    <form method="POST" action="/">
        <textarea name="review" rows="6" cols="60" placeholder="Nhập review ở đây..." required></textarea><br /><br />
        <button type="submit">Dự đoán</button>
    </form>
    {% if prediction_text %}
    <h3>{{ prediction_text }}</h3>
    {% endif %}
</body>
</html>
"""

# Ghi file templates/index.html
with open("templates/index.html", "w", encoding="utf-8") as f:
    f.write(html_content)

print("Đã tạo file templates/index.html thành công!")
# Out:
# Đã tạo file templates/index.html thành công!

# %%
import os



# Nội dung file home.html
home_html = """
<!DOCTYPE html>
<html lang="vi">
<head>
  <meta charset="UTF-8" />
  <title>Sentiment Analysis for Vietnamese Language</title>
  <link href="https://fonts.googleapis.com/css2?family=Poppins:wght@600&display=swap" rel="stylesheet" />
  <style>
    * {
      margin: 0;
      padding: 0;
      box-sizing: border-box;
    }
    body {
      font-family: 'Poppins', sans-serif;
      min-height: 100vh;
      background: linear-gradient(135deg, #b8c6db, #f5f7fa);
      display: flex;
      align-items: center;
      justify-content: center;
      padding: 50px 20px;
      position: relative;
      overflow-x: hidden;
    }
    .container {
      display: flex;
      flex-wrap: wrap;
      align-items: center;
      background: white;
      border-radius: 25px;
      box-shadow: 0 20px 40px rgba(92, 51, 204, 0.25);
      padding: 50px;
      max-width: 1000px;
      width: 100%;
      gap: 40px;
      transition: transform 0.3s ease;
    }
    .container:hover {
      transform: translateY(-10px);
      box-shadow: 0 30px 60px rgba(92, 51, 204, 0.35);
    }
    .text-content {
      flex: 1 1 400px;
      padding-right: 30px;
    }
    .text-content h1 {
      font-size: 48px;
      color: #5c33cc;
      margin-bottom: 25px;
      font-weight: 700;
      text-shadow: 1px 1px 4px rgba(92, 51, 204, 0.25);
    }
    .text-content p {
      font-size: 20px;
      color: #555;
      margin-bottom: 40px;
      line-height: 1.5;
      letter-spacing: 0.03em;
    }
    .btn-start {
      padding: 16px 45px;
      font-size: 18px;
      background: linear-gradient(45deg, #6a47e2, #8a66f2);
      color: white;
      border: none;
      border-radius: 50px;
      cursor: pointer;
      font-weight: 700;
      box-shadow: 0 6px 15px rgba(106, 71, 226, 0.5);
      transition: all 0.3s ease;
      letter-spacing: 0.05em;
      text-decoration: none;
      display: inline-block;
    }
    .btn-start:hover {
      background: linear-gradient(45deg, #8a66f2, #6a47e2);
      box-shadow: 0 10px 20px rgba(138, 102, 242, 0.7);
      transform: scale(1.05);
    }
    .image-content {
      flex: 1 1 400px;
      text-align: center;
      transition: transform 0.3s ease;
      border-radius: 20px;
      overflow: hidden;
      box-shadow: 0 10px 25px rgba(92, 51, 204, 0.2);
      background: #f9f7ff;
    }
    .image-content img {
      max-width: 100%;
      height: auto;
      display: inline-block;
      border-radius: 20px;
      transition: transform 0.3s ease;
    }
    .image-content:hover img {
      transform: scale(1.05);
      filter: drop-shadow(0 10px 15px rgba(92, 51, 204, 0.3));
    }
    footer {
      position: fixed;
      bottom: 15px;
      width: 100%;
      text-align: center;
      font-size: 14px;
      color: #777;
      font-weight: 600;
      border-top: 1px solid #ddd;
      padding-top: 10px;
      background: #f5f7facc;
      backdrop-filter: saturate(180%) blur(8px);
      user-select: none;
    }
    @media (max-width: 850px) {
      .container {
        flex-direction: column;
        padding: 30px 20px;
      }
      .text-content, .image-content {
        padding: 0;
        flex: unset;
      }
      .text-content h1 {
        font-size: 36px;
      }
      .btn-start {
        width: 100%;
        text-align: center;
      }
    }
  </style>
</head>
<body>

  <div class="container">
    <div class="text-content">
      <h1>Sentiment Analysis for Vietnamese Language</h1>
      <p>Detect real or fake reviews using AI-powered Natural Language Processing technology.</p>
      <a href="{{ url_for('index') }}" class="btn-start">Start Analysis</a>
    </div>
    <div class="image-content">
      <img src="{{ url_for('static', filename='Virtual reality-cuate.svg') }}" alt="AI Review Illustration" />
    </div>
  </div>

  <footer>
    Designed by Phuong Loan
  </footer>

</body>
</html>
"""

# Ghi file home.html
with open("templates/home.html", "w", encoding="utf-8") as f:
    f.write(home_html)

print("Đã tạo file templates/home.html thành công!")
# Out:
# Đã tạo file templates/home.html thành công!

# %%
from flask import Flask, render_template, request
import joblib
import numpy as np
from gensim.models import Word2Vec
import os

app = Flask(__name__)

base_dir = os.getcwd()
svm_model_path = os.path.join(base_dir, "svm_model.pkl")
w2v_model_path = os.path.join(base_dir, "word2vec.model")

svm_model = joblib.load(svm_model_path)
w2v_model = Word2Vec.load(w2v_model_path)

def sentence_to_vec(sentence, model):
    words = sentence.lower().split()
    vec = np.zeros(model.vector_size)
    count = 0
    for w in words:
        if w in model.wv:
            vec += model.wv[w]
            count += 1
    if count != 0:
        vec /= count
    return vec

@app.route('/')
def home():
    return render_template('home.html')

@app.route('/index', methods=['GET', 'POST'])
def index():
    prediction_text = ""
    if request.method == 'POST':
        review = request.form.get('review', '')
        if review.strip():
            X_vec = sentence_to_vec(review, w2v_model).reshape(1, -1)
            prediction = svm_model.predict(X_vec)[0]
            prediction_text = f"Kết quả dự đoán: {prediction}"
        else:
            prediction_text = "Vui lòng nhập review hợp lệ."
    return render_template('index.html', prediction_text=prediction_text)

if __name__ == "__main__":
    app.run(debug=True, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %%
<a href="{{ url_for('index') }}" class="btn-start">Start Analysis</a>

# %%
from flask import Flask, request, render_template
import joblib
import numpy as np
from gensim.models import Word2Vec
import os
import threading

app = Flask(__name__)

base_dir = os.getcwd()
svm_model_path = os.path.join(base_dir, "svm_model.pkl")
w2v_model_path = os.path.join(base_dir, "word2vec.model")

svm_model = joblib.load(svm_model_path)
w2v_model = Word2Vec.load(w2v_model_path)

def sentence_to_vec(sentence, model):
    words = sentence.lower().split()
    vec = np.zeros(model.vector_size)
    count = 0
    for w in words:
        if w in model.wv:
            vec += model.wv[w]
            count += 1
    if count != 0:
        vec /= count
    return vec

@app.route("/", methods=["GET", "POST"])
def index():
    prediction_text = ""
    if request.method == "POST":
        review = request.form.get("review", "")
        if review.strip():
            X_vec = sentence_to_vec(review, w2v_model).reshape(1, -1)
            prediction = svm_model.predict(X_vec)[0]
            prediction_text = f"Kết quả dự đoán: {prediction}"
        else:
            prediction_text = "Vui lòng nhập review hợp lệ."
    return render_template("index.html", prediction_text=prediction_text)

def run_app():
    app.run(debug=True, use_reloader=False)

import threading
thread = threading.Thread(target=run_app)
thread.start()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
